# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
fig.add_subplot(3, 1, (1, 2))
# Out:
# <Axes: >

# %%
fig = plt.figure()

fig.add_subplot(331)
ax1 = fig.add_subplot(3, 3, 1)  # equivalent but more general

fig.add_subplot(332, frameon=False)  # subplot with no frame
fig.add_subplot(333, projection='polar')  # polar subplot
fig.add_subplot(334, sharex=ax1)  # subplot sharing x-axis with ax1
fig.add_subplot(335, facecolor="red")  # red subplot
fig.add_subplot(313, facecolor="green")  # red subplot

# ax1.remove()  # delete ax1 from the figure
# fig.add_subplot(ax1)  # add ax1 back to the figure
# Out:
# <Axes: >

# %%
import  matplotlib.pyplot as plt

fig =plt.figure(figsize=(8,6), gridspec_kw={'height_ratios': [1,3,1]},)
fig.subplots_adjust(bottom=0.025, left=0.025, top = 0.975, right=0.975)

X = [ (3,1,1), (3,3,4), (3,3,5), (3,3,6), (3,1,3)]
for nrows, ncols, plot_number in X:
    sub = fig.add_subplot(nrows, ncols, plot_number, bo)
    sub.set_xticks([])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 import  matplotlib.pyplot as plt
# ----> 3 fig =plt.figure(figsize=(8,6), gridspec_kw={'height_ratios': [1,3,1]},)
#       4 fig.subplots_adjust(bottom=0.025, left=0.025, top = 0.975, right=0.975)
#       6 X = [ (3,1,1), (3,3,4), (3,3,5), (3,3,6), (3,1,3)]
#
# File ~/anaconda3/envs/diffusion-lm/lib/python3.11/site-packages/matplotlib/pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# ...

# %%
# Import pyplot module
import matplotlib.pyplot as plt

# Defining subplots
fig, ax = plt.subplots(3, 1, figsize=(18, 18), gridspec_kw={"height_ratios": [6, 3,3]})

# Preparing data
x = [10, 20, 30, 40]
y = [100, 200, 300, 400]

# Creating subplots
ax[0].plot(x, y)
ax[1].plot(x, y)
ax[2].plot(x, y)

# Display result
